# %%
import pandas as pd
df=pd.read_csv("/content/grades_withnulls.csv")
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
import pandas as pd
df=pd.read_csv("/content/grades_withnulls.csv",sep=" ")
print(df)
# Out:
#    Names,Initials,SEM1,SEM2,SEM3,Grade,Placed
# 0                       Joe,K,9.8,10,9.9,A+,1
# 1                    Rajesh,M,8.9,9.1,9.3,A,1
# 2                     Kissan,V,9.9,9.8,10,A,0
# 3                        Mary,N,7.7,8,NaN,B,0
# 4                     Jeen,K,9.8,9.1,9.9,A+,1
# 5                       Raj,M,8.9,9.1,9.3,A,1
# 6                      Hassan,V,9.9,9,9.2,A,1
# 7                        Mari,N,7.7,8,7.1,B,1
# 8                     Jess,K,NaN,9.1,9.9,A+,1
# 9                    Rajini,M,NaN,9.1,9.3,A,0
# 10                    Kiran,V,NaN,9.3,9.2,A,0
# 11                       Maya,N,7.7,8,7.1,B,0
# 12                   Jolin,K,9.8,9.1,9.9,A+,1
# 13                   Rajesh,M,8.9,9.1,9.3,A,1
# 14                      Riya,M,9.3,9.9,10,A,1
# 15                     Sana,V,9.9,9.3,9.2,A,0
# 16                         Mark,N,7.7,8,7,B,0

# %%
import pandas as pd
df=pd.read_csv("/content/grades_withnulls.csv")
print(df)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
import pandas as pd
df=pd.read_csv("/content/diabetcsv.xlsx.csv")
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df=pd.read_csv("/content/diabetcsv.csv",sep=" ")
print(df.head())
print(df.tail(n=10))
# Out:
#     preg,plas,pres,skin,insu,mass,pedi,age,class
# 0    6,148,72,35,0,33.6,0.627,50,tested_positive
# 1     1,85,66,29,0,26.6,0.351,31,tested_negative
# 2     8,183,64,0,0,23.3,0.672,32,tested_positive
# 3    1,89,66,23,94,28.1,0.167,21,tested_negative
# 4  0,137,40,35,168,43.1,2.288,33,tested_positive
#        preg,plas,pres,skin,insu,mass,pedi,age,class
# 758      1,106,76,0,0,37.5,0.197,26,tested_negative
# 759      6,190,92,0,0,35.5,0.278,66,tested_positive
# 760     2,88,58,26,16,28.4,0.766,22,tested_negative
# 761       9,170,74,31,0,44,0.403,43,tested_positive
# 762       9,89,62,0,0,22.5,0.142,33,tested_negative
# 763  10,101,76,48,180,32.9,0.171,63,tested_negative
# 764      2,122,70,27,0,36.8,0.34,27,tested_negative
# 765   5,121,72,23,112,26.2,0.245,30,tested_negative
# 766      1,126,60,0,0,30.1,0.349,47,tested_positive
# 767      1,93,70,31,0,30.4,0.315,23,tested_negative

# %%
df=pd.read_csv("/content/diabetcsv.csv",sep=" ")
print(df.describe)
# Out:
# <bound method NDFrame.describe of        preg,plas,pres,skin,insu,mass,pedi,age,class
# 0       6,148,72,35,0,33.6,0.627,50,tested_positive
# 1        1,85,66,29,0,26.6,0.351,31,tested_negative
# 2        8,183,64,0,0,23.3,0.672,32,tested_positive
# 3       1,89,66,23,94,28.1,0.167,21,tested_negative
# 4     0,137,40,35,168,43.1,2.288,33,tested_positive
# ..                                              ...
# 763  10,101,76,48,180,32.9,0.171,63,tested_negative
# 764      2,122,70,27,0,36.8,0.34,27,tested_negative
# 765   5,121,72,23,112,26.2,0.245,30,tested_negative
# 766      1,126,60,0,0,30.1,0.349,47,tested_positive
# 767      1,93,70,31,0,30.4,0.315,23,tested_negative
#
# [768 rows x 1 columns]>

# %%
df=pd.read_csv("/content/diabetcsv.csv",sep=" ")
print(df.shape)
print(df.shape[0])
print(df.shape[1])
# Out:
# (768, 1)
# 768
# 1

# %%
#create list with column names
df=pd.read_csv("/content/diabetcsv.csv",sep=" ")
print(df.columns)
# Out:
# Index(['preg,plas,pres,skin,insu,mass,pedi,age,class'], dtype='object')

# %%
#making null values
df=pd.read_csv("/content/diabetcsv.csv",sep=" ")
df2=df.copy()
df2.loc[2:5,'SEM1']=None
de2.head(7)
# Out:
#     preg,plas,pres,skin,insu,mass,pedi,age,class
# 0    6,148,72,35,0,33.6,0.627,50,tested_positive
# 1     1,85,66,29,0,26.6,0.351,31,tested_negative
# 2     8,183,64,0,0,23.3,0.672,32,tested_positive
# 3    1,89,66,23,94,28.1,0.167,21,tested_negative
# 4  0,137,40,35,168,43.1,2.288,33,tested_positive
# 5     5,116,74,0,0,25.6,0.201,30,tested_negative
# 6      3,78,50,32,88,31,0.248,26,tested_positive

# %%
df2.isnull().head(7)
# Out:
#    preg,plas,pres,skin,insu,mass,pedi,age,class  SEM1
# 0                                         False  True
# 1                                         False  True
# 2                                         False  True
# 3                                         False  True
# 4                                         False  True
# 5                                         False  True
# 6                                         False  True

# %%
df2.isnull().tail(7)
# Out:
#      preg,plas,pres,skin,insu,mass,pedi,age,class  SEM1
# 761                                         False  True
# 762                                         False  True
# 763                                         False  True
# 764                                         False  True
# 765                                         False  True
# 766                                         False  True
# 767                                         False  True

# %%
print(df2.isnull().sum())
# Out:
# preg,plas,pres,skin,insu,mass,pedi,age,class      0
# SEM1                                            768
# dtype: int64

# %%
#extracting column
print(df2['SEM1'])
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 763   NaN
# 764   NaN
# 765   NaN
# 766   NaN
# 767   NaN
# Name: SEM1, Length: 768, dtype: float64

# %%
#printing one row as series
print(df2.loc[1])
# Out:
# preg,plas,pres,skin,insu,mass,pedi,age,class    1,85,66,29,0,26.6,0.351,31,tested_negative
# SEM1                                                                                   NaN
# Name: 1, dtype: object

# %%
#printing one row as series
print(df2.loc[6:11])
# Out:
#      preg,plas,pres,skin,insu,mass,pedi,age,class  SEM1
# 6       3,78,50,32,88,31,0.248,26,tested_positive   NaN
# 7      10,115,0,0,0,35.3,0.134,29,tested_negative   NaN
# 8   2,197,70,45,543,30.5,0.158,53,tested_positive   NaN
# 9         8,125,96,0,0,0,0.232,54,tested_positive   NaN
# 10     4,110,92,0,0,37.6,0.191,30,tested_negative   NaN
# 11      10,168,74,0,0,38,0.537,34,tested_positive   NaN

# %%
print(df2.loc[6:11]==None)
# Out:
#     preg,plas,pres,skin,insu,mass,pedi,age,class   SEM1
# 6                                          False  False
# 7                                          False  False
# 8                                          False  False
# 9                                          False  False
# 10                                         False  False
# 11                                         False  False

# %%
df2.loc[10:15,['Names',]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-e5e88a8f033d> in <cell line: 1>()
# ----> 1 df2.loc[10:15,['Names',]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# ...

# %%
df2.loc[:7,["names"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-0cd2b7da464c> in <cell line: 1>()
# ----> 1 df2.loc[:7,["names"]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# ...

# %%
print(df2.loc[6:11]==None)
# Out:
#     preg,plas,pres,skin,insu,mass,pedi,age,class   SEM1
# 6                                          False  False
# 7                                          False  False
# 8                                          False  False
# 9                                          False  False
# 10                                         False  False
# 11                                         False  False

# %%
df3=df2.copy()
df3
# Out:
#        preg,plas,pres,skin,insu,mass,pedi,age,class  SEM1
# 0       6,148,72,35,0,33.6,0.627,50,tested_positive   NaN
# 1        1,85,66,29,0,26.6,0.351,31,tested_negative   NaN
# 2        8,183,64,0,0,23.3,0.672,32,tested_positive   NaN
# 3       1,89,66,23,94,28.1,0.167,21,tested_negative   NaN
# 4     0,137,40,35,168,43.1,2.288,33,tested_positive   NaN
# ..                                              ...   ...
# 763  10,101,76,48,180,32.9,0.171,63,tested_negative   NaN
# 764      2,122,70,27,0,36.8,0.34,27,tested_negative   NaN
# 765   5,121,72,23,112,26.2,0.245,30,tested_negative   NaN
# 766      1,126,60,0,0,30.1,0.349,47,tested_positive   NaN
# 767      1,93,70,31,0,30.4,0.315,23,tested_negative   NaN
#
# [768 rows x 2 columns]

# %%
df.plot.line(subplots=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-eef73b0374a3> in <cell line: 1>()
# ----> 1 df.plot.line(subplots=True)
#
# NameError: name 'df' is not defined
