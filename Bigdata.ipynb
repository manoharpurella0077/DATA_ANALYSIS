# %%
import numpy as np
#Generate a large volume of random data(e.g.,1 million data points)
volume_data=np.random.rand(1000000)
print("Volume of data:",volume_data)
# Out:
# Volume of data: [0.99311862 0.52732896 0.86811778 ... 0.76558548 0.48912863 0.7508277 ]

# %%
import time
#simulate streaming data every second for 10 seconds
for i in range(10):
  velocity_data=np.random.rand()#Generate random data
  print("Velocity data point:",velocity_data)
  time.sleep(1)#wait for 1 second to simulate real-time data stream
# Out:
# Velocity data point: 0.20984972101678245
# Velocity data point: 0.14870204886342542
# Velocity data point: 0.7731669880252457
# Velocity data point: 0.2724828047925577
# Velocity data point: 0.7922246825890079
# Velocity data point: 0.5858278381901028
# Velocity data point: 0.39043117813995265
# Velocity data point: 0.580125138816362
# Velocity data point: 0.4960945775781389
# Velocity data point: 0.40154891767324163

# %%
#stuctured data
structured_data={'id':1,'name':'jhon','age':30}
print(structured_data)
#semi_structured_data(JSON)
semi_structured_data={'person':{'name':'Alice','age':25,'city':'New York'}}
print(semi_structured_data)
unstructured_data="this is a sample text document .It can contain any information in free form "
print(unstructured_data)
# Out:
# {'id': 1, 'name': 'jhon', 'age': 30}
# {'person': {'name': 'Alice', 'age': 25, 'city': 'New York'}}
# this is a sample text document .It can contain any information in free form

# %%
import random
#Generate some random data with noise
veracity_data=[random.choice([1,2,3,None])for _ in range(20)]
print("Veracity data:",veracity_data)
# Out:
# Veracity data: [1, 1, 1, 1, 2, None, 1, 1, 3, 1, None, 3, None, 2, 3, 1, None, 1, 3, None]
